# %% [markdown]
# # Barabási-Albert Tests

# %%
import networkx as nx
import seaborn as sns
from noisy_graphs.noisy_graph import NoisyGraph

# %%
ba_graph = nx.barabasi_albert_graph(n=10, m=9)

# %%
nx.draw(ba_graph)

# %%
for node, degree in ba_graph.degree:
    print(f"k({node}) = {degree}")
# Out:
# k(0) = 1
# k(1) = 1
# k(2) = 1
# k(3) = 1
# k(4) = 1
# k(5) = 1
# k(6) = 1
# k(7) = 1
# k(8) = 1
# k(9) = 9

# %%
g = nx.barabasi_albert_graph(n=1000, m=5)
deg = [len(nbrs) for n,nbrs in g.adj.items()]
sns.displot(deg)

# %%
g = nx.barabasi_albert_graph(n=1000, m=500)
deg = [len(nbrs) for n,nbrs in g.adj.items()]
sns.displot(deg)

# %%
g = nx.barabasi_albert_graph(n=1000, m=900)
deg = [len(nbrs) for n,nbrs in g.adj.items()]
sns.displot(deg)
